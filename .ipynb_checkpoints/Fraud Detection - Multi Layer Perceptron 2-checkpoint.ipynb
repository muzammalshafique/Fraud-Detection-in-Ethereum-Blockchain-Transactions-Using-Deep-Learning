# %%
import pandas as pd

# Replace 'path_to_your_csv.csv' with the actual path to your CSV file
df = pd.read_csv('data.csv')

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['FLAG'] = le.fit_transform(df['FLAG'])  # Converts 'Fraud' to 1 and 'Non-Fraud' to 0

# %%
from sklearn.preprocessing import StandardScaler

features = df.drop('FLAG', axis=1)  # Exclude the target variable
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# %%
X = features_scaled
y = df['FLAG'].values

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter
import matplotlib.pyplot as plt

smote = SMOTE(sampling_strategy='minority', k_neighbors=5)
X_res, y_res = smote.fit_resample(X, y)

# Assuming 'X' and 'y' are your features and labels before SMOTE
# and 'X_res' and 'y_res' are the features and labels after SMOTE
counter_before = Counter(y)
counter_after = Counter(y_res)

# Create a DataFrame from the counters
df = pd.DataFrame({'Emotion before oversampling': counter_before, 'Emotion after oversampling': counter_after})

# Create a bar plot
df.plot(kind='bar')

# Set the title and labels
plt.title('Class Distribution before and after SMOTE - MLP')
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.xticks(rotation=45)  # Rotate class labels to avoid overlap

# Show the plot
plt.tight_layout()  # Adjust the plot to ensure everything fits without overlap
plt.show()

# %%
from sklearn.feature_selection import mutual_info_classif

info_gain = mutual_info_classif(X_res, y_res)
top_features_indices = info_gain.argsort()[-10:][::-1]  # Get indices of top 10 features
X_top_features = X_res[:, top_features_indices]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_top_features, y_res, test_size=0.2, random_state=42)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Assuming X_train, y_train, X_test, and y_test are already defined and preprocessed
n_features = X_train.shape[1]  # replace with the actual number of features in your dataset

# Define the MLP model architecture using Keras
model = Sequential()
model.add(Dense(50, input_shape=(n_features,), activation='relu'))
model.add(Dense(1))  # Output layer; for regression no activation function is used

# Compile the model
model.compile(optimizer=Adam(), loss='mean_squared_error',metrics=['mean_absolute_error'])

# Train the model
history = model.fit(X_train, y_train, validation_split=0.2, epochs=10, batch_size=10, verbose=1)

# Evaluate the model on the test set
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print the evaluation metrics
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R²): {r2:.2f}")

# Print the summary of the model
model.summary()
# Out:
# Epoch 1/10
# 1959/1959 [==============================] - 9s 4ms/step - loss: 0.2251 - mean_absolute_error: 0.3328 - val_loss: 0.1293 - val_mean_absolute_error: 0.2816
# Epoch 2/10
# 1959/1959 [==============================] - 9s 4ms/step - loss: 0.1462 - mean_absolute_error: 0.2674 - val_loss: 0.1142 - val_mean_absolute_error: 0.2573
# Epoch 3/10
# 1959/1959 [==============================] - 8s 4ms/step - loss: 0.1220 - mean_absolute_error: 0.2501 - val_loss: 0.1085 - val_mean_absolute_error: 0.2448
# Epoch 4/10
# 1959/1959 [==============================] - 8s 4ms/step - loss: 0.0998 - mean_absolute_error: 0.2337 - val_loss: 0.0997 - val_mean_absolute_error: 0.2258
# Epoch 5/10
# 1959/1959 [==============================] - 7s 4ms/step - loss: 0.0937 - mean_absolute_error: 0.2191 - val_loss: 0.0851 - val_mean_absolute_error: 0.2064
# Epoch 6/10
# 1959/1959 [==============================] - 8s 4ms/step - loss: 0.1014 - mean_absolute_error: 0.2020 - val_loss: 0.0810 - val_mean_absolute_error: 0.1994
# Epoch 7/10
# 1959/1959 [==============================] - 10s 5ms/step - loss: 0.0779 - mean_absolute_error: 0.1865 - val_loss: 0.0645 - val_mean_absolute_error: 0.1749
# Epoch 8/10
# 1959/1959 [==============================] - 8s 4ms/step - loss: 0.0736 - mean_absolute_error: 0.1705 - val_loss: 0.0592 - val_mean_absolute_error: 0.1637
# Epoch 9/10
# 1959/1959 [==============================] - 9s 4ms/step - loss: 0.0815 - mean_absolute_error: 0.1577 - val_loss: 0.0697 - val_mean_absolute_error: 0.1656
# Epoch 10/10
# 1959/1959 [==============================] - 9s 5ms/step - loss: 0.0758 - mean_absolute_error: 0.1465 - val_loss: 0.0524 - val_mean_absolute_error: 0.1415
# 192/192 [==============================] - 1s 2ms/step
# Mean Squared Error (MSE): 0.60
# Root Mean Squared Error (RMSE): 0.78
# Mean Absolute Error (MAE): 0.15
# R-squared (R²): -1.41
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                550
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 601
# Trainable params: 601
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss (MSE) - MLP')
plt.ylabel('Loss (MSE)')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(history.history['mean_absolute_error'], label='Train MAE')
plt.plot(history.history['val_mean_absolute_error'], label='Validation MAE')
plt.title('Model MAE - MLP')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.show()

# %%
# import shap
# # SHAP Values - Explain the model's predictions
# explainer = shap.KernelExplainer(mlp.predict, X_train)
# shap_values = explainer.shap_values(X_test, nsamples=10)  # nsamples is a parameter you can tweak

# # Plot SHAP values
# feature_names = list(df.columns)
# shap.summary_plot(shap_values, X_test, feature_names=feature_names)  # Replace feature_names with your actual features
